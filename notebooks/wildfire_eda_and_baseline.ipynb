# %% [markdown]
# # Wildfire Ignition-Risk EDA and Baseline\n\nThis notebook explores the wildfire sample dataset and validates the baseline training path.

# %%
from pathlib import Path\nimport pandas as pd\n\npath = Path('../data/sample/wildfire_training_sample.csv')\nframe = pd.read_csv(path)\nframe.head()

# %%
frame['ignition_next_24h'].value_counts(normalize=True)

# %%
from train_wildfire_ignition_model import train_model\n\nbundle, metrics = train_model(frame)\nmetrics
